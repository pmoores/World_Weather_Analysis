# %%
# 3. Create a new set of 2,000 random latitudes and longitudes
# Import the needed dependencies - Pandas, matplotlib.pyplot, NumPy
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combinations and pack as pairs using the zip() function
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Unpack the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# 4. Get the nearest city using the citipy module
# Import citypy from citypy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 732

# %%
# 5. Perform an API call with the OpenWeatherMap
# Import Requests library
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bed12b228c2ad23e4950ef491cbf1fb1

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval.   ")
print("----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL, record, and set numbers and the city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1

    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # 6. Retrieve required information from the API call
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Solution from discussion with Tutor David Chao on Slack Aug 7-2021
        city_description = city_weather["weather"][0]["description"]
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval.
# ----------------------------
# Processing Record 1 of Set 1 | namatanai
# Processing Record 2 of Set 1 | norman wells
# Processing Record 3 of Set 1 | rockland
# Processing Record 4 of Set 1 | montauban
# Processing Record 5 of Set 1 | svirstroy
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | bethel
# Processing Record 8 of Set 1 | avarua
# Processing Record 9 of Set 1 | bratslav
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | deputatskiy
# Processing Record 13 of Set 1 | marawi
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | kibakwe
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | banda aceh
# Processing Record 18 of Set 1 | fiumicino
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | rawson
# Processing Record 21 of Set 1 | tessalit
# Processing Record 22 of Set 1 | okato
# Processing Record 23 of Set 1 | flin flon
# Processing Record 24 of Set 1 | conceicao da barra
# Processing Record 25 of Set 1 | san carlos de bariloche
# Processing Record 26 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 1 | gazanjyk
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | mwinilunga
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | saint-philippe
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 1 | villarrica
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | san cristobal
# Processing Record 37 of Set 1 | castro
# Processing Record 38 of Set 1 | torbay
# Processing Record 39 of Set 1 | iquique
# Processing Record 40 of Set 1 | avera
# Processing Record 41 of Set 1 | nikolskoye
# Processing Record 42 of Set 1 | alice town
# Processing Record 43 of Set 1 | ahipara
# Processing Record 44 of Set 1 | tasiilaq
# Processing Record 45 of Set 1 | hamilton
# Processing Record 46 of Set 1 | cabo san lucas
# Processing Record 47 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | klaksvik
# Processing Record 1 of Set 2 | dikson
# Processing Record 2 of Set 2 | juneau
# Processing Record 3 of Set 2 | khovu-aksy
# Processing Record 4 of Set 2 | pevek
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | anadyr
# Processing Record 7 of Set 2 | kalakamati
# Processing Record 8 of Set 2 | new norfolk
# Processing Record 9 of Set 2 | el badari
# City not found. Skipping...
# Processing Record 10 of Set 2 | lazaro cardenas
# Processing Record 11 of Set 2 | paita
# Processing Record 12 of Set 2 | port alfred
# Processing Record 13 of Set 2 | masvingo
# Processing Record 14 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 2 | itumba
# Processing Record 16 of Set 2 | lompoc
# Processing Record 17 of Set 2 | ancud
# Processing Record 18 of Set 2 | hilo
# Processing Record 19 of Set 2 | georgetown
# Processing Record 20 of Set 2 | fort nelson
# Processing Record 21 of Set 2 | kapaa
# Processing Record 22 of Set 2 | hermanus
# Processing Record 23 of Set 2 | tuatapere
# Processing Record 24 of Set 2 | tiksi
# Processing Record 25 of Set 2 | biak
# Processing Record 26 of Set 2 | cherskiy
# Processing Record 27 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 2 | nosivka
# Processing Record 29 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 2 | turukhansk
# Processing Record 31 of Set 2 | balkanabat
# Processing Record 32 of Set 2 | pisco
# Processing Record 33 of Set 2 | chokurdakh
# Processing Record 34 of Set 2 | miro khan
# Processing Record 35 of Set 2 | sur
# Processing Record 36 of Set 2 | severo-kurilsk
# Processing Record 37 of Set 2 | belfast
# Processing Record 38 of Set 2 | mbandaka
# Processing Record 39 of Set 2 | chuy
# Processing Record 40 of Set 2 | zheleznodorozhnyy
# Processing Record 41 of Set 2 | les cayes
# Processing Record 42 of Set 2 | sitka
# Processing Record 43 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 2 | union
# Processing Record 45 of Set 2 | mar del plata
# Processing Record 46 of Set 2 | luba
# Processing Record 47 of Set 2 | namibe
# Processing Record 48 of Set 2 | lubango
# Processing Record 49 of Set 2 | hasaki
# Processing Record 50 of Set 2 | ranong
# Processing Record 1 of Set 3 | saskylakh
# Processing Record 2 of Set 3 | moranbah
# Processing Record 3 of Set 3 | de aar
# Processing Record 4 of Set 3 | bathsheba
# Processing Record 5 of Set 3 | harrisburg
# Processing Record 6 of Set 3 | qaanaaq
# Processing Record 7 of Set 3 | te anau
# Processing Record 8 of Set 3 | butaritari
# Processing Record 9 of Set 3 | djibo
# Processing Record 10 of Set 3 | moba
# Processing Record 11 of Set 3 | stoyba
# City not found. Skipping...
# Processing Record 12 of Set 3 | bilibino
# Processing Record 13 of Set 3 | arraial do cabo
# Processing Record 14 of Set 3 | pangnirtung
# Processing Record 15 of Set 3 | mehamn
# Processing Record 16 of Set 3 | carnarvon
# Processing Record 17 of Set 3 | khash
# Processing Record 18 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 3 | amahai
# Processing Record 20 of Set 3 | kieta
# Processing Record 21 of Set 3 | dali
# Processing Record 22 of Set 3 | hohhot
# Processing Record 23 of Set 3 | hithadhoo
# Processing Record 24 of Set 3 | ilulissat
# Processing Record 25 of Set 3 | provideniya
# Processing Record 26 of Set 3 | port elizabeth
# Processing Record 27 of Set 3 | wakkanai
# Processing Record 28 of Set 3 | luwuk
# Processing Record 29 of Set 3 | ostrovnoy
# Processing Record 30 of Set 3 | tuggurt
# City not found. Skipping...
# Processing Record 31 of Set 3 | sao joao da barra
# Processing Record 32 of Set 3 | saldanha
# Processing Record 33 of Set 3 | itoman
# Processing Record 34 of Set 3 | saint-pierre
# Processing Record 35 of Set 3 | uray
# Processing Record 36 of Set 3 | nokaneng
# Processing Record 37 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 38 of Set 3 | popondetta
# Processing Record 39 of Set 3 | pinheiro
# Processing Record 40 of Set 3 | faanui
# Processing Record 41 of Set 3 | boyolangu
# Processing Record 42 of Set 3 | east london
# Processing Record 43 of Set 3 | karaton
# Processing Record 44 of Set 3 | san patricio
# Processing Record 45 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 3 | haifa
# Processing Record 48 of Set 3 | lamar
# Processing Record 49 of Set 3 | barranca
# Processing Record 50 of Set 3 | poum
# Processing Record 1 of Set 4 | hovd
# Processing Record 2 of Set 4 | opobo
# City not found. Skipping...
# Processing Record 3 of Set 4 | oussouye
# Processing Record 4 of Set 4 | rosita
# Processing Record 5 of Set 4 | hualmay
# Processing Record 6 of Set 4 | gejiu
# Processing Record 7 of Set 4 | lata
# Processing Record 8 of Set 4 | hervey bay
# Processing Record 9 of Set 4 | acarau
# Processing Record 10 of Set 4 | ambilobe
# Processing Record 11 of Set 4 | lavrentiya
# Processing Record 12 of Set 4 | esperance
# Processing Record 13 of Set 4 | katherine
# Processing Record 14 of Set 4 | kahului
# Processing Record 15 of Set 4 | maseru
# Processing Record 16 of Set 4 | yellowknife
# Processing Record 17 of Set 4 | fairbanks
# Processing Record 18 of Set 4 | quatre cocos
# Processing Record 19 of Set 4 | airai
# Processing Record 20 of Set 4 | hami
# Processing Record 21 of Set 4 | mumford
# Processing Record 22 of Set 4 | turan
# Processing Record 23 of Set 4 | thompson
# Processing Record 24 of Set 4 | leningradskiy
# Processing Record 25 of Set 4 | harper
# Processing Record 26 of Set 4 | saint george
# Processing Record 27 of Set 4 | tchollire
# Processing Record 28 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 4 | linguere
# Processing Record 30 of Set 4 | muroto
# Processing Record 31 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 32 of Set 4 | luderitz
# Processing Record 33 of Set 4 | paamiut
# Processing Record 34 of Set 4 | anloga
# Processing Record 35 of Set 4 | bubaque
# Processing Record 36 of Set 4 | taltal
# Processing Record 37 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 4 | bengkulu
# Processing Record 39 of Set 4 | coquimbo
# Processing Record 40 of Set 4 | labuan
# Processing Record 41 of Set 4 | guican
# Processing Record 42 of Set 4 | solsvik
# City not found. Skipping...
# Processing Record 43 of Set 4 | walvis bay
# Processing Record 44 of Set 4 | riaba
# City not found. Skipping...
# Processing Record 45 of Set 4 | jamestown
# Processing Record 46 of Set 4 | meulaboh
# Processing Record 47 of Set 4 | murdochville
# Processing Record 48 of Set 4 | tuktoyaktuk
# Processing Record 49 of Set 4 | victoria
# Processing Record 50 of Set 4 | kodiak
# Processing Record 1 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 5 | parkersburg
# Processing Record 3 of Set 5 | rudbar
# Processing Record 4 of Set 5 | berdigestyakh
# Processing Record 5 of Set 5 | sayyan
# Processing Record 6 of Set 5 | san rafael
# Processing Record 7 of Set 5 | ossora
# Processing Record 8 of Set 5 | mizdah
# Processing Record 9 of Set 5 | yandoon
# City not found. Skipping...
# Processing Record 10 of Set 5 | yulara
# Processing Record 11 of Set 5 | bambous virieux
# Processing Record 12 of Set 5 | morondava
# Processing Record 13 of Set 5 | moshkovo
# Processing Record 14 of Set 5 | saint anthony
# Processing Record 15 of Set 5 | guerrero negro
# Processing Record 16 of Set 5 | ponta delgada
# Processing Record 17 of Set 5 | bara
# Processing Record 18 of Set 5 | miandrivazo
# Processing Record 19 of Set 5 | yumen
# Processing Record 20 of Set 5 | ashland
# Processing Record 21 of Set 5 | kaspiyskiy
# Processing Record 22 of Set 5 | toora-khem
# Processing Record 23 of Set 5 | guadalupe y calvo
# Processing Record 24 of Set 5 | wajima
# Processing Record 25 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 26 of Set 5 | isangel
# Processing Record 27 of Set 5 | adrar
# Processing Record 28 of Set 5 | mamallapuram
# Processing Record 29 of Set 5 | hambantota
# Processing Record 30 of Set 5 | khipro
# Processing Record 31 of Set 5 | gigmoto
# Processing Record 32 of Set 5 | dalmeny
# Processing Record 33 of Set 5 | vieste
# Processing Record 34 of Set 5 | novikovo
# Processing Record 35 of Set 5 | palana
# Processing Record 36 of Set 5 | cape canaveral
# Processing Record 37 of Set 5 | bressuire
# Processing Record 38 of Set 5 | bereda
# Processing Record 39 of Set 5 | caravelas
# Processing Record 40 of Set 5 | codrington
# Processing Record 41 of Set 5 | antalaha
# Processing Record 42 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 43 of Set 5 | mendi
# Processing Record 44 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 5 | kavieng
# Processing Record 46 of Set 5 | chumphon
# Processing Record 47 of Set 5 | korla
# Processing Record 48 of Set 5 | atambua
# Processing Record 49 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 5 | upernavik
# Processing Record 1 of Set 6 | kalabo
# Processing Record 2 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 6 | yeppoon
# Processing Record 4 of Set 6 | moengo
# Processing Record 5 of Set 6 | muisne
# Processing Record 6 of Set 6 | alofi
# Processing Record 7 of Set 6 | mount gambier
# Processing Record 8 of Set 6 | necochea
# Processing Record 9 of Set 6 | brainerd
# Processing Record 10 of Set 6 | bataipora
# Processing Record 11 of Set 6 | komsomolskiy
# Processing Record 12 of Set 6 | husavik
# Processing Record 13 of Set 6 | grindavik
# Processing Record 14 of Set 6 | lagoa
# Processing Record 15 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 6 | kingaroy
# Processing Record 17 of Set 6 | hurghada
# Processing Record 18 of Set 6 | asau
# Processing Record 19 of Set 6 | arendonk
# Processing Record 20 of Set 6 | vestmanna
# Processing Record 21 of Set 6 | sao filipe
# Processing Record 22 of Set 6 | aswan
# Processing Record 23 of Set 6 | honiara
# Processing Record 24 of Set 6 | murgab
# Processing Record 25 of Set 6 | denpasar
# Processing Record 26 of Set 6 | mogadishu
# Processing Record 27 of Set 6 | wattegama
# Processing Record 28 of Set 6 | ribeira grande
# Processing Record 29 of Set 6 | makakilo city
# Processing Record 30 of Set 6 | dingle
# Processing Record 31 of Set 6 | ouallam
# Processing Record 32 of Set 6 | brae
# Processing Record 33 of Set 6 | killorglin
# Processing Record 34 of Set 6 | lancut
# Processing Record 35 of Set 6 | kruisfontein
# Processing Record 36 of Set 6 | tura
# Processing Record 37 of Set 6 | shenjiamen
# Processing Record 38 of Set 6 | khatanga
# Processing Record 39 of Set 6 | ust-kuyga
# Processing Record 40 of Set 6 | churachandpur
# Processing Record 41 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 6 | maulvi bazar
# City not found. Skipping...
# Processing Record 43 of Set 6 | la ronge
# Processing Record 44 of Set 6 | roma
# Processing Record 45 of Set 6 | kathu
# Processing Record 46 of Set 6 | novoagansk
# Processing Record 47 of Set 6 | mao
# Processing Record 48 of Set 6 | riyadh
# Processing Record 49 of Set 6 | neiafu
# Processing Record 50 of Set 6 | sao jose da coroa grande
# Processing Record 1 of Set 7 | alta floresta
# Processing Record 2 of Set 7 | barcelos
# Processing Record 3 of Set 7 | puerto ayora
# Processing Record 4 of Set 7 | ndele
# Processing Record 5 of Set 7 | pingliang
# Processing Record 6 of Set 7 | rorvik
# Processing Record 7 of Set 7 | visby
# Processing Record 8 of Set 7 | buala
# Processing Record 9 of Set 7 | muyezerskiy
# Processing Record 10 of Set 7 | vestmannaeyjar
# Processing Record 11 of Set 7 | heze
# Processing Record 12 of Set 7 | ormara
# Processing Record 13 of Set 7 | gubskaya
# Processing Record 14 of Set 7 | yavatmal
# Processing Record 15 of Set 7 | sampit
# Processing Record 16 of Set 7 | lebu
# Processing Record 17 of Set 7 | pajapan
# Processing Record 18 of Set 7 | katsuura
# Processing Record 19 of Set 7 | mount isa
# Processing Record 20 of Set 7 | constitucion
# Processing Record 21 of Set 7 | borinskoye
# Processing Record 22 of Set 7 | sortland
# Processing Record 23 of Set 7 | susah
# City not found. Skipping...
# Processing Record 24 of Set 7 | altamira
# Processing Record 25 of Set 7 | ust-tsilma
# Processing Record 26 of Set 7 | bannu
# Processing Record 27 of Set 7 | manali
# Processing Record 28 of Set 7 | broken hill
# Processing Record 29 of Set 7 | port blair
# Processing Record 30 of Set 7 | chicama
# Processing Record 31 of Set 7 | nagaur
# Processing Record 32 of Set 7 | fuerte olimpo
# Processing Record 33 of Set 7 | fortuna
# Processing Record 34 of Set 7 | manacapuru
# Processing Record 35 of Set 7 | texarkana
# Processing Record 36 of Set 7 | yar-sale
# Processing Record 37 of Set 7 | linhares
# Processing Record 38 of Set 7 | aklavik
# Processing Record 39 of Set 7 | faya
# Processing Record 40 of Set 7 | kemlya
# Processing Record 41 of Set 7 | portel
# Processing Record 42 of Set 7 | aranda de duero
# Processing Record 43 of Set 7 | touros
# Processing Record 44 of Set 7 | horodkivka
# Processing Record 45 of Set 7 | camopi
# Processing Record 46 of Set 7 | aanekoski
# Processing Record 47 of Set 7 | saint-augustin
# Processing Record 48 of Set 7 | vardo
# Processing Record 49 of Set 7 | berlevag
# Processing Record 50 of Set 7 | teahupoo
# Processing Record 1 of Set 8 | san quintin
# Processing Record 2 of Set 8 | beringovskiy
# Processing Record 3 of Set 8 | lodja
# Processing Record 4 of Set 8 | nanortalik
# Processing Record 5 of Set 8 | morant bay
# Processing Record 6 of Set 8 | flinders
# Processing Record 7 of Set 8 | grande-riviere
# City not found. Skipping...
# Processing Record 8 of Set 8 | paracuru
# Processing Record 9 of Set 8 | tromso
# Processing Record 10 of Set 8 | college
# Processing Record 11 of Set 8 | kaitangata
# Processing Record 12 of Set 8 | alyangula
# Processing Record 13 of Set 8 | boa vista
# Processing Record 14 of Set 8 | trinidad
# Processing Record 15 of Set 8 | amanganj
# Processing Record 16 of Set 8 | cusset
# Processing Record 17 of Set 8 | cidreira
# Processing Record 18 of Set 8 | zhigansk
# Processing Record 19 of Set 8 | mackay
# Processing Record 20 of Set 8 | longyearbyen
# Processing Record 21 of Set 8 | bilma
# Processing Record 22 of Set 8 | mozarlandia
# Processing Record 23 of Set 8 | catuday
# Processing Record 24 of Set 8 | nuwara eliya
# Processing Record 25 of Set 8 | okandja
# City not found. Skipping...
# Processing Record 26 of Set 8 | yining
# Processing Record 27 of Set 8 | bollnas
# Processing Record 28 of Set 8 | ono
# Processing Record 29 of Set 8 | narsaq
# Processing Record 30 of Set 8 | chimore
# Processing Record 31 of Set 8 | armacao dos buzios
# City not found. Skipping...
# Processing Record 32 of Set 8 | cockburn town
# Processing Record 33 of Set 8 | rabak
# Processing Record 34 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 35 of Set 8 | qaqortoq
# Processing Record 36 of Set 8 | coahuayana
# Processing Record 37 of Set 8 | athabasca
# Processing Record 38 of Set 8 | maceio
# Processing Record 39 of Set 8 | yerbogachen
# Processing Record 40 of Set 8 | sechura
# Processing Record 41 of Set 8 | yarkovo
# Processing Record 42 of Set 8 | yarada
# Processing Record 43 of Set 8 | roblin
# Processing Record 44 of Set 8 | north branch
# Processing Record 45 of Set 8 | cam ranh
# Processing Record 46 of Set 8 | mahebourg
# Processing Record 47 of Set 8 | port keats
# Processing Record 48 of Set 8 | santa lucia
# Processing Record 49 of Set 8 | solnechnyy
# Processing Record 50 of Set 8 | taos
# Processing Record 1 of Set 9 | gat
# Processing Record 2 of Set 9 | carlyle
# Processing Record 3 of Set 9 | lorengau
# Processing Record 4 of Set 9 | sumenep
# Processing Record 5 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 6 of Set 9 | linchuan
# City not found. Skipping...
# Processing Record 7 of Set 9 | shizukuishi
# Processing Record 8 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 9 | smoky lake
# Processing Record 10 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 11 of Set 9 | moroto
# Processing Record 12 of Set 9 | golden
# Processing Record 13 of Set 9 | bardsir
# Processing Record 14 of Set 9 | sindor
# Processing Record 15 of Set 9 | methoni
# Processing Record 16 of Set 9 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 17 of Set 9 | shetpe
# Processing Record 18 of Set 9 | ruteng
# Processing Record 19 of Set 9 | bokspits
# City not found. Skipping...
# Processing Record 20 of Set 9 | bay roberts
# Processing Record 21 of Set 9 | miranorte
# City not found. Skipping...
# Processing Record 22 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 9 | karachi
# Processing Record 24 of Set 9 | havoysund
# Processing Record 25 of Set 9 | nanakuli
# Processing Record 26 of Set 9 | shubarshi
# Processing Record 27 of Set 9 | poroshkovo
# Processing Record 28 of Set 9 | los llanos de aridane
# Processing Record 29 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 30 of Set 9 | mecca
# Processing Record 31 of Set 9 | guaruja
# Processing Record 32 of Set 9 | nikolayevskaya
# Processing Record 33 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 9 | moree
# Processing Record 35 of Set 9 | maarianhamina
# Processing Record 36 of Set 9 | shakawe
# Processing Record 37 of Set 9 | bandarbeyla
# Processing Record 38 of Set 9 | whitehorse
# Processing Record 39 of Set 9 | alibag
# Processing Record 40 of Set 9 | skjervoy
# Processing Record 41 of Set 9 | luanda
# Processing Record 42 of Set 9 | kabalo
# Processing Record 43 of Set 9 | chipiona
# Processing Record 44 of Set 9 | carupano
# Processing Record 45 of Set 9 | luganville
# Processing Record 46 of Set 9 | lethem
# Processing Record 47 of Set 9 | puerto leguizamo
# Processing Record 48 of Set 9 | payo
# Processing Record 49 of Set 9 | oranjestad
# Processing Record 50 of Set 9 | eganville
# Processing Record 1 of Set 10 | samarai
# Processing Record 2 of Set 10 | karratha
# Processing Record 3 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 4 of Set 10 | ponta do sol
# Processing Record 5 of Set 10 | norrtalje
# Processing Record 6 of Set 10 | matagami
# Processing Record 7 of Set 10 | russkoye
# Processing Record 8 of Set 10 | pathein
# Processing Record 9 of Set 10 | chumikan
# Processing Record 10 of Set 10 | camacha
# Processing Record 11 of Set 10 | wuda
# Processing Record 12 of Set 10 | gizo
# Processing Record 13 of Set 10 | coolum beach
# Processing Record 14 of Set 10 | souillac
# Processing Record 15 of Set 10 | benguela
# Processing Record 16 of Set 10 | bima
# Processing Record 17 of Set 10 | henties bay
# Processing Record 18 of Set 10 | mozirje
# Processing Record 19 of Set 10 | strezhevoy
# Processing Record 20 of Set 10 | addi ugri
# City not found. Skipping...
# Processing Record 21 of Set 10 | roald
# Processing Record 22 of Set 10 | dunshaughlin
# Processing Record 23 of Set 10 | el angel
# Processing Record 24 of Set 10 | hadrut
# Processing Record 25 of Set 10 | olinda
# Processing Record 26 of Set 10 | jaipur hat
# City not found. Skipping...
# Processing Record 27 of Set 10 | santiago del estero
# Processing Record 28 of Set 10 | nova olimpia
# Processing Record 29 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 30 of Set 10 | nioro
# Processing Record 31 of Set 10 | xiaoweizhai
# Processing Record 32 of Set 10 | taoudenni
# Processing Record 33 of Set 10 | laguna de perlas
# Processing Record 34 of Set 10 | aldama
# Processing Record 35 of Set 10 | broome
# Processing Record 36 of Set 10 | comodoro rivadavia
# Processing Record 37 of Set 10 | mercedes
# Processing Record 38 of Set 10 | hobyo
# Processing Record 39 of Set 10 | izumo
# Processing Record 40 of Set 10 | san carlos park
# Processing Record 41 of Set 10 | katobu
# Processing Record 42 of Set 10 | leh
# Processing Record 43 of Set 10 | zonguldak
# Processing Record 44 of Set 10 | inhambane
# Processing Record 45 of Set 10 | dhidhdhoo
# Processing Record 46 of Set 10 | okhotsk
# Processing Record 47 of Set 10 | kasongo
# Processing Record 48 of Set 10 | abu dhabi
# Processing Record 49 of Set 10 | abnub
# Processing Record 50 of Set 10 | hay river
# Processing Record 1 of Set 11 | talnakh
# Processing Record 2 of Set 11 | nishihara
# Processing Record 3 of Set 11 | virginia beach
# Processing Record 4 of Set 11 | tiffin
# Processing Record 5 of Set 11 | byron bay
# Processing Record 6 of Set 11 | hachinohe
# Processing Record 7 of Set 11 | the valley
# Processing Record 8 of Set 11 | sambava
# Processing Record 9 of Set 11 | campbeltown
# Processing Record 10 of Set 11 | mondeville
# Processing Record 11 of Set 11 | iqaluit
# Processing Record 12 of Set 11 | clyde river
# Processing Record 13 of Set 11 | haapiti
# Processing Record 14 of Set 11 | placido de castro
# Processing Record 15 of Set 11 | djambala
# Processing Record 16 of Set 11 | pitimbu
# Processing Record 17 of Set 11 | morehead
# Processing Record 18 of Set 11 | esso
# Processing Record 19 of Set 11 | ayorou
# Processing Record 20 of Set 11 | voyvozh
# Processing Record 21 of Set 11 | nabire
# Processing Record 22 of Set 11 | santa ana
# Processing Record 23 of Set 11 | rio grande
# Processing Record 24 of Set 11 | vila
# Processing Record 25 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 11 | camacari
# Processing Record 28 of Set 11 | aquiraz
# Processing Record 29 of Set 11 | sofiysk
# City not found. Skipping...
# Processing Record 30 of Set 11 | forestville
# Processing Record 31 of Set 11 | dolores
# Processing Record 32 of Set 11 | tutoia
# Processing Record 33 of Set 11 | porto torres
# Processing Record 34 of Set 11 | dubbo
# Processing Record 35 of Set 11 | conselice
# Processing Record 36 of Set 11 | plettenberg bay
# Processing Record 37 of Set 11 | khachrod
# Processing Record 38 of Set 11 | alice springs
# Processing Record 39 of Set 11 | batagay-alyta
# Processing Record 40 of Set 11 | le vauclin
# Processing Record 41 of Set 11 | bamako
# Processing Record 42 of Set 11 | celestun
# Processing Record 43 of Set 11 | road town
# Processing Record 44 of Set 11 | fukue
# Processing Record 45 of Set 11 | muros
# Processing Record 46 of Set 11 | panzhihua
# Processing Record 47 of Set 11 | manokwari
# Processing Record 48 of Set 11 | surab
# Processing Record 49 of Set 11 | cap malheureux
# Processing Record 50 of Set 11 | guymon
# Processing Record 1 of Set 12 | belaya gora
# Processing Record 2 of Set 12 | coronel fabriciano
# Processing Record 3 of Set 12 | zhenhai
# Processing Record 4 of Set 12 | cabedelo
# Processing Record 5 of Set 12 | saint-leu
# Processing Record 6 of Set 12 | bay city
# Processing Record 7 of Set 12 | banjar
# Processing Record 8 of Set 12 | ous
# Processing Record 9 of Set 12 | pindi gheb
# Processing Record 10 of Set 12 | umm kaddadah
# Processing Record 11 of Set 12 | wasilla
# Processing Record 12 of Set 12 | geraldton
# Processing Record 13 of Set 12 | baruun-urt
# Processing Record 14 of Set 12 | kurilsk
# Processing Record 15 of Set 12 | sayan
# Processing Record 16 of Set 12 | punta alta
# Processing Record 17 of Set 12 | clarksville
# Processing Record 18 of Set 12 | cayenne
# Processing Record 19 of Set 12 | hokitika
# Processing Record 20 of Set 12 | otane
# Processing Record 21 of Set 12 | kyshtovka
# Processing Record 22 of Set 12 | lusambo
# Processing Record 23 of Set 12 | plainview
# Processing Record 24 of Set 12 | chara
# Processing Record 25 of Set 12 | gweta
# Processing Record 26 of Set 12 | sebastian
# Processing Record 27 of Set 12 | bosobolo
# Processing Record 28 of Set 12 | linxia
# Processing Record 29 of Set 12 | bardiyah
# Processing Record 30 of Set 12 | burns lake
# Processing Record 31 of Set 12 | aloleng
# Processing Record 32 of Set 12 | trairi
# Processing Record 33 of Set 12 | olafsvik
# Processing Record 34 of Set 12 | teya
# Processing Record 35 of Set 12 | danville
# Processing Record 36 of Set 12 | adre
# Processing Record 37 of Set 12 | ambon
# Processing Record 38 of Set 12 | bar harbor
# Processing Record 39 of Set 12 | itupiranga
# Processing Record 40 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 12 | mareeba
# Processing Record 42 of Set 12 | chulman
# Processing Record 43 of Set 12 | merauke
# Processing Record 44 of Set 12 | mogzon
# Processing Record 45 of Set 12 | san clemente
# Processing Record 46 of Set 12 | sao gabriel da cachoeira
# Processing Record 47 of Set 12 | ariquemes
# Processing Record 48 of Set 12 | asfi
# Processing Record 49 of Set 12 | tonj
# Processing Record 50 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 1 of Set 13 | richards bay
# Processing Record 2 of Set 13 | fos-sur-mer
# Processing Record 3 of Set 13 | miri
# Processing Record 4 of Set 13 | solenzo
# Processing Record 5 of Set 13 | puno
# Processing Record 6 of Set 13 | orlik
# Processing Record 7 of Set 13 | ojinaga
# Processing Record 8 of Set 13 | kibondo
# Processing Record 9 of Set 13 | koungou
# Processing Record 10 of Set 13 | scarborough
# Processing Record 11 of Set 13 | khonsa
# Processing Record 12 of Set 13 | smithers
# Processing Record 13 of Set 13 | kedrovyy
# Processing Record 14 of Set 13 | knysna
# Processing Record 15 of Set 13 | aasiaat
# Processing Record 16 of Set 13 | makaha
# Processing Record 17 of Set 13 | tual
# Processing Record 18 of Set 13 | pizarro
# Processing Record 19 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 20 of Set 13 | beisfjord
# Processing Record 21 of Set 13 | mae sai
# Processing Record 22 of Set 13 | marion
# Processing Record 23 of Set 13 | magadan
# Processing Record 24 of Set 13 | pacific grove
# Processing Record 25 of Set 13 | lumajang
# Processing Record 26 of Set 13 | thinadhoo
# Processing Record 27 of Set 13 | coihaique
# Processing Record 28 of Set 13 | santiago
# Processing Record 29 of Set 13 | sinaloa
# Processing Record 30 of Set 13 | bonfim
# Processing Record 31 of Set 13 | paragominas
# Processing Record 32 of Set 13 | rocha
# Processing Record 33 of Set 13 | safaga
# Processing Record 34 of Set 13 | calama
# Processing Record 35 of Set 13 | tahta
# Processing Record 36 of Set 13 | margate
# Processing Record 37 of Set 13 | suna
# Processing Record 38 of Set 13 | shchuchye
# City not found. Skipping...
# Processing Record 39 of Set 13 | mayo
# Processing Record 40 of Set 13 | kharan
# Processing Record 41 of Set 13 | praia
# Processing Record 42 of Set 13 | valparaiso
# Processing Record 43 of Set 13 | bandiagara
# Processing Record 44 of Set 13 | mankera
# Processing Record 45 of Set 13 | kamenka
# Processing Record 46 of Set 13 | kamaishi
# Processing Record 47 of Set 13 | udachnyy
# Processing Record 48 of Set 13 | vanavara
# Processing Record 49 of Set 13 | beliu
# Processing Record 50 of Set 13 | corum
# Processing Record 1 of Set 14 | nyurba
# Processing Record 2 of Set 14 | yeehaw junction
# City not found. Skipping...
# Processing Record 3 of Set 14 | jerantut
# Processing Record 4 of Set 14 | tezu
# Processing Record 5 of Set 14 | namanyere
# Processing Record 6 of Set 14 | lima
# Processing Record 7 of Set 14 | naze
# Processing Record 8 of Set 14 | burnie
# Processing Record 9 of Set 14 | homer
# Processing Record 10 of Set 14 | dunedin
# Processing Record 11 of Set 14 | dongsheng
# Processing Record 12 of Set 14 | beloha
# Processing Record 13 of Set 14 | surt
# Processing Record 14 of Set 14 | sisimiut
# Processing Record 15 of Set 14 | port lincoln
# Processing Record 16 of Set 14 | stornoway
# Processing Record 17 of Set 14 | sangar
# Processing Record 18 of Set 14 | bintulu
# Processing Record 19 of Set 14 | palmer
# Processing Record 20 of Set 14 | stettler
# Processing Record 21 of Set 14 | pishin
# Processing Record 22 of Set 14 | binzhou
# Processing Record 23 of Set 14 | kazanskaya
# Processing Record 24 of Set 14 | evensk
# Processing Record 25 of Set 14 | ingham
# Processing Record 26 of Set 14 | surgut
# Processing Record 27 of Set 14 | insch
# Processing Record 28 of Set 14 | grand-santi
# Processing Record 29 of Set 14 | eston
# Processing Record 30 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 31 of Set 14 | laguna
# Processing Record 32 of Set 14 | severnyy
# Processing Record 33 of Set 14 | vicuna
# Processing Record 34 of Set 14 | zhongshu
# Processing Record 35 of Set 14 | waipawa
# Processing Record 36 of Set 14 | mushie
# Processing Record 37 of Set 14 | harrismith
# Processing Record 38 of Set 14 | ranfurly
# Processing Record 39 of Set 14 | bocas del toro
# Processing Record 40 of Set 14 | sola
# Processing Record 41 of Set 14 | aguimes
# Processing Record 42 of Set 14 | marsaxlokk
# Processing Record 43 of Set 14 | irbil
# Processing Record 44 of Set 14 | carutapera
# Processing Record 45 of Set 14 | maralal
# Processing Record 46 of Set 14 | port-gentil
# Processing Record 47 of Set 14 | amapa
# Processing Record 48 of Set 14 | severodvinsk
# Processing Record 49 of Set 14 | ewa beach
# Processing Record 50 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 1 of Set 15 | nzerekore
# Processing Record 2 of Set 15 | concepcion
# Processing Record 3 of Set 15 | douglas
# Processing Record 4 of Set 15 | bela
# Processing Record 5 of Set 15 | oksfjord
# Processing Record 6 of Set 15 | winchester
# Processing Record 7 of Set 15 | horqueta
# Processing Record 8 of Set 15 | kyzyl-suu
# Processing Record 9 of Set 15 | wagar
# Processing Record 10 of Set 15 | mabay
# Processing Record 11 of Set 15 | oktyabrskiy
# Processing Record 12 of Set 15 | saint-jean-port-joli
# Processing Record 13 of Set 15 | sao felix do xingu
# Processing Record 14 of Set 15 | crotone
# Processing Record 15 of Set 15 | lamu
# Processing Record 16 of Set 15 | shache
# Processing Record 17 of Set 15 | acapulco
# Processing Record 18 of Set 15 | canchungo
# Processing Record 19 of Set 15 | azangaro
# Processing Record 20 of Set 15 | santa maria
# Processing Record 21 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 15 | shiraz
# Processing Record 23 of Set 15 | itarema
# Processing Record 24 of Set 15 | emerald
# Processing Record 25 of Set 15 | prokopion
# Processing Record 26 of Set 15 | baykit
# Processing Record 27 of Set 15 | meru
# Processing Record 28 of Set 15 | birjand
# Processing Record 29 of Set 15 | balaguer
# Processing Record 30 of Set 15 | keshabpur
# Processing Record 31 of Set 15 | houma
# Processing Record 32 of Set 15 | malakal
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# 7. Add the data to new DataFrame
city_data_df = pd.DataFrame(city_data)

# Confirm if DataFrame has the correct information
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Namatanai  -3.6667  152.4333     77.40        82          79
# 1  Norman Wells  65.2820 -126.8329     48.24        71          90
# 2      Rockland  41.1668  -74.0496     88.86        55         100
# 3     Montauban  44.0833    1.5000     69.12        71          33
# 4     Svirstroy  60.7999   33.7248     61.25        98         100
# 5       Mataura -46.1927  168.8643     34.48        99         100
# 6        Bethel  41.3712  -73.4140     86.88        65           1
# 7        Avarua -21.2078 -159.7750     77.05        73           5
# 8      Bratslav  48.8226   28.9407     60.01        66           0
# 9        Hobart -42.8794  147.3294     35.26        88          98
#
#    Wind Speed Country Current Description
# 0        6.06      PG       moderate rain
# 1        9.22      CA     overcast clouds
# 2        1.01      US     overcast clouds
# 3        7.00      FR    scattered clouds
# 4        9.28      RU     overcast clouds
# 5        0.94      NZ     overcast clouds
# 6        9.22      US           clear sky
# 7        2.30      CK           clear sky
# 8        5.08      UA           clear sky
# 9        3.00      AU     overcast clouds

# %%
# Reorder the columns to match Deliverable 1 requirements
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Display the new columns order
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Namatanai      PG  -3.6667  152.4333     77.40        82          79
# 1  Norman Wells      CA  65.2820 -126.8329     48.24        71          90
# 2      Rockland      US  41.1668  -74.0496     88.86        55         100
# 3     Montauban      FR  44.0833    1.5000     69.12        71          33
# 4     Svirstroy      RU  60.7999   33.7248     61.25        98         100
# 5       Mataura      NZ -46.1927  168.8643     34.48        99         100
# 6        Bethel      US  41.3712  -73.4140     86.88        65           1
# 7        Avarua      CK -21.2078 -159.7750     77.05        73           5
# 8      Bratslav      UA  48.8226   28.9407     60.01        66           0
# 9        Hobart      AU -42.8794  147.3294     35.26        88          98
#
#    Wind Speed Current Description
# 0        6.06       moderate rain
# 1        9.22     overcast clouds
# 2        1.01     overcast clouds
# 3        7.00    scattered clouds
# 4        9.28     overcast clouds
# 5        0.94     overcast clouds
# 6        9.22           clear sky
# 7        2.30           clear sky
# 8        5.08           clear sky
# 9        3.00     overcast clouds

# %%
# 8. Export the DataFrame as a csv file
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
